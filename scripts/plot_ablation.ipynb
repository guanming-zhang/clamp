# %%
from matplotlib import pyplot as plt
import os
import numpy
import json
import re

# %%
root_dir = '/home/richard/Empire-home/code/clap/simulations/imagenet/ablation_rs'
x_name = "rs"
x = list()
acc1,acc5 = list(),list()
for item in os.listdir(root_dir):
    if os.path.isdir(os.path.join(root_dir,item)) and "run" in item:
        sub_dir = os.path.join(root_dir,item)
        lc_dir = os.path.join(sub_dir,"lc","lr_0.2")
        with open(os.path.join(lc_dir,"results.json"),"r") as f:
            result = json.load(f)
        acc1.append(result["test_acc1"])
        acc5.append(result["test_acc5"])
        match = re.search(x_name + r'-([\d.]+)', sub_dir)
        value = float(match.group(1))
        x.append(value)
# Out:
# dir0#DATA#-n_views-4-dataset-IMAGENET1K-30percent-#SSL#-lr-8.0-batch_size-512-momentum-0.0-lw0-0.0-lw2-0.0-weight_decay-1e-06-rs-2.0-run-00
# dir1#DATA#-n_views-4-dataset-IMAGENET1K-30percent-#SSL#-lr-8.0-batch_size-512-momentum-0.0-lw0-0.0-lw2-0.0-weight_decay-1e-06-rs-4.0-run-00
# dir2#DATA#-n_views-4-dataset-IMAGENET1K-30percent-#SSL#-lr-8.0-batch_size-512-momentum-0.0-lw0-0.0-lw2-0.0-weight_decay-1e-06-rs-6.0-run-00
# dir3#DATA#-n_views-4-dataset-IMAGENET1K-30percent-#SSL#-lr-8.0-batch_size-512-momentum-0.0-lw0-0.0-lw2-0.0-weight_decay-1e-06-rs-8.0-run-00
# dir4#DATA#-n_views-4-dataset-IMAGENET1K-30percent-#SSL#-lr-8.0-batch_size-512-momentum-0.0-lw0-0.0-lw2-0.0-weight_decay-1e-06-rs-10.0-run-00

# %%
fig = plt.figure()
ax1 = fig.add_axes(111)
ax1.plot(x,acc1,linestyle='--', marker='o', color='blue')
ax1.set_ylabel("top 1 accuracy",fontsize=14)
ax1.set_xlabel("$r_s$",fontsize=14)
# Out:
# Text(0.5, 0, '$r_s$')
